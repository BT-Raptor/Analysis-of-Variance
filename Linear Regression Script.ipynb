# %% [markdown]
# Load the libaries & Data

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import SequentialFeatureSelector
np.set_printoptions(suppress=True)

all_data=pd.read_csv('opp.csv')
all_data.head()
# Out:
#    case  site  Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0     1     1  Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1     2     1  Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2     3     1  Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3     4     1  Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4     5     1  Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
#
#    earconch   eye  chest  belly
# 0      54.5  15.2   28.0   36.0
# 1      51.2  16.0   28.5   33.0
# 2      51.9  15.5   30.0   34.0
# 3      52.2  15.2   28.0   34.0
# 4      53.2  15.1   28.5   33.0

# %%
all_data=all_data.dropna()
all_data['hdlngth_2']=all_data['hdlngth']**2
all_data['skullw_2']=all_data['skullw']**2
all_data['totlngth_2']=all_data['totlngth']**2
all_data['taill_2']=all_data['taill']**2
all_data['footlgth_2']=all_data['footlgth']**2
all_data['earconch_2']=all_data['earconch']**2
all_data['eye_2']=all_data['eye']**2
all_data['chest_2']=all_data['chest']**2
all_data['belly_2']=all_data['belly']**2

all_data['sex_m']=np.where(all_data['sex']=='m',1,0)
all_data['Pop_Vic']=np.where(all_data['Pop']=='Vic',1,0)
all_data['site_1']=np.where(all_data['site']==1,1,0)
all_data['site_2']=np.where(all_data['site']==2,1,0)
all_data['site_3']=np.where(all_data['site']==3,1,0)
all_data['site_4']=np.where(all_data['site']==4,1,0)
all_data['site_5']=np.where(all_data['site']==5,1,0)
all_data['site_6']=np.where(all_data['site']==6,1,0)
all_data['site_7']=np.where(all_data['site']==7,1,0)

all_data=all_data.drop(['case','site','Pop','sex'],axis=1)
all_data.head()
# Out:
#    age  hdlngth  skullw  totlngth  taill  footlgth  earconch   eye  chest  \
# 0  8.0     94.1    60.4      89.0   36.0      74.5      54.5  15.2   28.0
# 1  6.0     92.5    57.6      91.5   36.5      72.5      51.2  16.0   28.5
# 2  6.0     94.0    60.0      95.5   39.0      75.4      51.9  15.5   30.0
# 3  6.0     93.2    57.1      92.0   38.0      76.1      52.2  15.2   28.0
# 4  2.0     91.5    56.3      85.5   36.0      71.0      53.2  15.1   28.5
#
#    belly  ...  belly_2  sex_m  Pop_Vic  site_1  site_2  site_3  site_4  \
# 0   36.0  ...   1296.0      1        1       1       0       0       0
# 1   33.0  ...   1089.0      0        1       1       0       0       0
# 2   34.0  ...   1156.0      0        1       1       0       0       0
# 3   34.0  ...   1156.0      0        1       1       0       0       0
# 4   33.0  ...   1089.0      0        1       1       0       0       0
#
#    site_5  site_6  site_7
# 0       0       0       0
# 1       0       0       0
# 2       0       0       0
# 3       0       0       0
# 4       0       0       0
#
# [5 rows x 28 columns]

# %%
import statsmodels.api as sm
from scipy import stats

X = all_data.drop(['age'],axis=1)
y = all_data[['age']]

# %%
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
model = est.fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    age   R-squared:                       0.392
# Model:                            OLS   Adj. R-squared:                  0.189
# Method:                 Least Squares   F-statistic:                     1.933
# Date:                Sat, 25 Jun 2022   Prob (F-statistic):             0.0154
# Time:                        21:40:57   Log-Likelihood:                -183.33
# No. Observations:                 101   AIC:                             418.7
# Df Residuals:                      75   BIC:                             486.7
# Df Model:                          25
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -191.7861    102.719     -1.867      0.066    -396.414      12.842
# hdlngth        3.9378      2.411      1.633      0.107      -0.865       8.740
# skullw         2.9471      1.821      1.619      0.110      -0.680       6.574
# totlngth      -0.3015      2.115     -0.143      0.887      -4.514       3.911
# taill          1.5889      2.856      0.556      0.580      -4.101       7.278
# footlgth      -2.6624      1.698     -1.568      0.121      -6.044       0.719
# earconch       1.3778      1.742      0.791      0.431      -2.092       4.848
# eye           -2.4863      4.147     -0.600      0.551     -10.747       5.775
# chest          1.0554      2.536      0.416      0.679      -3.997       6.108
# belly         -0.0096      1.426     -0.007      0.995      -2.851       2.832
# hdlngth_2     -0.0209      0.013     -1.614      0.111      -0.047       0.005
# skullw_2      -0.0237      0.015     -1.576      0.119      -0.054       0.006
# totlngth_2     0.0014      0.012      0.119      0.906      -0.023       0.025
# taill_2       -0.0200      0.038     -0.524      0.602      -0.096       0.056
# footlgth_2     0.0186      0.012      1.517      0.133      -0.006       0.043
# earconch_2    -0.0146      0.018     -0.818      0.416      -0.050       0.021
# eye_2          0.0843      0.136      0.621      0.537      -0.186       0.355
# chest_2       -0.0170      0.047     -0.363      0.718      -0.110       0.076
# belly_2        0.0014      0.021      0.066      0.947      -0.041       0.044
# sex_m          0.2365      0.432      0.547      0.586      -0.625       1.098
# Pop_Vic      -21.8032     12.270     -1.777      0.080     -46.246       2.640
# site_1       -10.9090      6.167     -1.769      0.081     -23.195       1.377
# site_2       -10.8943      6.134     -1.776      0.080     -23.113       1.324
# site_3       -34.0463     18.278     -1.863      0.066     -70.458       2.365
# site_4       -34.8765     17.973     -1.941      0.056     -70.680       0.927
# site_5       -33.2243     18.068     -1.839      0.070     -69.217       2.768
# site_6       -33.6342     17.939     -1.875      0.065     -69.370       2.102
# site_7       -34.2015     18.284     -1.871      0.065     -70.626       2.223
# ==============================================================================
# Omnibus:                        4.967   Durbin-Watson:                   1.707
# Prob(Omnibus):                  0.083   Jarque-Bera (JB):                4.332
# Skew:                           0.477   Prob(JB):                        0.115
# Kurtosis:                       3.344   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.76e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
